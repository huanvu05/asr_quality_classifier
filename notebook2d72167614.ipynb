# %%
# !git clone https://github.com/huanvu05/asr_quality_classifier.git
# Out:
# Cloning into 'asr_quality_classifier'...
# remote: Enumerating objects: 173, done.
# remote: Counting objects: 100% (173/173), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 173 (delta 95), reused 130 (delta 52), pack-reused 0 (from 0)
# Receiving objects: 100% (173/173), 128.20 KiB | 2.79 MiB/s, done.
# Resolving deltas: 100% (95/95), done.

# %%
# 1. Đảm bảo đứng đúng thư mục làm việc gốc của Kaggle
# %cd /kaggle/working

# 2. Tạo cấu trúc thư mục data bên trong repo asr_quality_classifier của bạn
# !mkdir -p asr_quality_classifier/data/audio
# !mkdir -p asr_quality_classifier/data/transcripts

# 3. Tải và cài đặt công cụ AzCopy v10 tương thích với Kaggle Linux
# !wget -O azcopy_v10.tar.gz https://aka.ms/downloadazcopy-v10-linux
# !tar -xf azcopy_v10.tar.gz --strip-components=1
# !chmod +x azcopy
# !rm azcopy_v10.tar.gz
print("[+] Cài đặt AzCopy thành công!")

# 4. Cấu hình Link SAS và Đường dẫn đích chuẩn xác trên Kaggle
SAS_URL = 'https://vsfaicskhaudio.blob.core.windows.net/intern-corpus/training_audio?se=2026-11-20&sp=racwl&spr=https&sv=2026-02-06&sr=c&sig=MiAnNLychnHq7xRdH7nUHqyQZ/qmaQy3Kb3emMUxoVE%3D'
DEST_PATH = '/kaggle/working/asr_quality_classifier/data/audio'

# 5. Tiến hành tải dữ liệu Audio bằng AzCopy
# !./azcopy copy '{SAS_URL}' '{DEST_PATH}' --recursive=true

# 6. Sắp xếp lại cấu trúc thư mục lồng nhau ngay trên Kaggle
# %cd /kaggle/working/asr_quality_classifier/data/audio
# !mv training_audio/data2 .
# !rm -rf training_audio

print("\n[OK] Đã tải xong! Giờ bạn bấm Refresh nút file bên trái Kaggle sẽ thấy thư mục dữ liệu xuất hiện tại:")
print("/kaggle/working/asr_quality_classifier/data/audio/data2")
# Out:
# /kaggle/working
# --2026-06-05 02:29:56--  https://aka.ms/downloadazcopy-v10-linux
# Resolving aka.ms (aka.ms)... 184.31.114.8
# Connecting to aka.ms (aka.ms)|184.31.114.8|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/Azure/azure-storage-azcopy/releases/download/v10.32.4/azcopy_linux_amd64_10.32.4.tar.gz [following]
# --2026-06-05 02:29:56--  https://github.com/Azure/azure-storage-azcopy/releases/download/v10.32.4/azcopy_linux_amd64_10.32.4.tar.gz
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !cp /kaggle/input/datasets/huanvu205/training/training.csv /kaggle/working/asr_quality_classifier/data/transcripts/training.csv

# %%
# %cd /kaggle/working
# Out:
# /kaggle/working

# %%
# %cd asr_quality_classifier
# !git pull origin main
# Out:
# [Errno 2] No such file or directory: 'asr_quality_classifier'
# /kaggle/working/asr_quality_classifier/data/audio
# From https://github.com/huanvu05/asr_quality_classifier
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# %cd asr_quality_classifier
# Out:
# /kaggle/working/asr_quality_classifier

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.8/434.8 kB 11.3 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 75.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 19.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: cuda-bindings
#     Found existing installation: cuda-bindings 13.2.0
#     Uninstalling cuda-bindings-13.2.0:
#       Successfully uninstalled cuda-bindings-13.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ...

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 511 bytes | 511.00 KiB/s, done.
# From https://github.com/huanvu05/asr_quality_classifier
#  * branch            main       -> FETCH_HEAD
#    363c0aa..8ee45a5  main       -> origin/main
# Updating 363c0aa..8ee45a5
# Fast-forward
#  src/config.py | 4 +++-
#  1 file changed, 3 insertions(+), 1 deletion(-)

# %%
# !python main.py --labels-path data/transcripts/training.csv
# Out:
# Starting Deep Audio Pipeline: run_20260603_083205_deep_audio
# Loading Whisper Encoder (openai/whisper-base) on cpu (Forced for compatibility)...
# ...
# Loading weights: 100%|█| 245/245 [00:00<00:00, 1531.56it/s, Materializing param=
# Extracting Deep Audio Embeddings: 100%|█████| 3500/3500 [30:58<00:00,  1.88it/s]
# Saved 3500 embeddings to data/run_20260603_083205_deep_audio_embeddings.pkl
# Starting PyTorch DNN Training...
# Traceback (most recent call last):
#   File "/kaggle/working/asr_quality_classifier/main.py", line 113, in <module>
#     main(args)
#   File "/kaggle/working/asr_quality_classifier/main.py", line 70, in main
#     oof_probs = evaluator.run_cv(X, y)
#                 ^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/asr_quality_classifier/src/evaluator.py", line 109, in run_cv
#     train_dataset = AudioDataset(X_train, y_train)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/asr_quality_classifier/src/model.py", line 8, in __init__
# ...

# %%
# !python main.py \
    --labels-path data/transcripts/training.csv \
    --skip-extraction \
    --features-path data/run_20260603_083205_deep_audio_embeddings.pkl
# Out:
# Starting Deep Audio Pipeline: run_20260603_090945_deep_audio
# Loading precomputed embeddings from data/run_20260603_083205_deep_audio_embeddings.pkl
# Starting PyTorch DNN Training...
# Fold 1 completed.
# Fold 2 completed.
# Fold 3 completed.
# Fold 4 completed.
# Fold 5 completed.
#
# ...
# FINAL EVALUATION REPORT (PyTorch DNN)
# ...
# Optimal Threshold: 0.4600
#               precision    recall  f1-score   support
#
#            0       0.36      0.37      0.37       904
#            1       0.78      0.77      0.78      2596
#
#     accuracy                           0.67      3500
#    macro avg       0.57      0.57      0.57      3500
# weighted avg       0.67      0.67      0.67      3500
#
# ROC-AUC: 0.6048
# Training final model on full dataset...
#
# [DONE] Artifacts saved locally in models:
# - PyTorch Model: models/run_20260603_090945_deep_audio_model.pth
# - Metadata: models/run_20260603_090945_deep_audio_metadata.json
# - Confusion Matrix: confusion_matrix.png

# %%
# !python main.py --labels-path data/transcripts/training.csv
# Out:
# Starting Deep Audio Pipeline: run_20260603_093627_deep_audio
# Loading Whisper Encoder (openai/whisper-base) on cpu (Forced for compatibility)...
# ...
# Loading weights: 100%|█| 245/245 [00:00<00:00, 1819.01it/s, Materializing param=
# Extracting Deep Audio Embeddings: 100%|█████| 3500/3500 [31:08<00:00,  1.87it/s]
# Saved 3500 embeddings to data/run_20260603_093627_deep_audio_embeddings.pkl
# Starting PyTorch DNN Training...
# Fold 1 completed.
# Fold 2 completed.
# Fold 3 completed.
# Fold 4 completed.
# Fold 5 completed.
#
# ...
# FINAL EVALUATION REPORT (PyTorch DNN)
# ...
# Optimal Threshold: 0.4600
#               precision    recall  f1-score   support
#
#            0       0.36      0.37      0.37       904
#            1       0.78      0.77      0.78      2596
#
#     accuracy                           0.67      3500
#    macro avg       0.57      0.57      0.57      3500
# weighted avg       0.67      0.67      0.67      3500
#
# ROC-AUC: 0.6048
# Training final model on full dataset...
# ...

# %%
# !python train_hybrid.py --emb data/run_20260603_093627_deep_audio_embeddings.pkl
# Out:
# Loading CSV from: /kaggle/working/asr_quality_classifier/data/transcripts/training.csv
# Loading Precomputed Embeddings from: data/run_20260603_093627_deep_audio_embeddings.pkl
# Detected embedding dimension: 512
# Aligning and building Hybrid Feature Matrix...
# 100%|███████████████████████████████████████| 3500/3500 [00:46<00:00, 74.52it/s]
#
# [INFO] Final Dataset Shape: X=(3500, 522), y=(3500,)
#
# Starting Stratified 5-Fold Cross-Validation...
# Fold 1 completed.
# Fold 2 completed.
# Fold 3 completed.
# Fold 4 completed.
# Fold 5 completed.
#
# Optimal Threshold Optimized to: 0.5300
# ...
# FINAL CLASSIFICATION REPORT (OOF)
# ...
#               precision    recall  f1-score   support
#
#            0       0.31      0.37      0.34       904
#            1       0.77      0.71      0.74      2596
#
#     accuracy                           0.63      3500
#    macro avg       0.54      0.54      0.54      3500
# weighted avg       0.65      0.63      0.64      3500
#
# ROC-AUC: 0.5535
#
# ...

# %%
# !pip install num2words
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 6.2 MB/s eta 0:00:00
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=d29689616f6f415f58624997925da143512830f7cff5ac000f0a57f848488dba
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built docopt
# ...

# %%
# !python main.py --labels-path data/transcripts/training.csv
# Out:
# Starting SOTA Pipeline: run_20260604_025406_sota_attention
# Loading Wav2Vec2 Encoder (facebook/wav2vec2-large-xlsr-53) on cuda...
# ...
# preprocessor_config.json: 100%|████████████████| 212/212 [00:00<00:00, 1.01MB/s]
# config.json: 1.77kB [00:00, 3.84MB/s]
# pytorch_model.bin: 100%|████████████████████| 1.27G/1.27G [00:06<00:00, 210MB/s]
# model.safetensors:   0%|                            | 0.00/1.27G [00:00<?, ?B/s]
# Loading weights:   0%|                                  | 0/422 [00:00<?, ?it/s]
# Loading weights:   0%| | 1/422 [00:00<00:00, 618.26it/s, Materializing param=enc
# Loading weights:   0%| | 1/422 [00:00<00:01, 251.35it/s, Materializing param=enc
# Loading weights:   0%| | 2/422 [00:00<00:01, 368.94it/s, Materializing param=enc
# Loading weights:   0%| | 2/422 [00:00<00:01, 270.79it/s, Materializing param=enc
# Loading weights:   1%| | 3/422 [00:00<00:01, 246.17it/s, Materializing param=enc
# ...

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 4), reused 6 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 866 bytes | 433.00 KiB/s, done.
# From https://github.com/huanvu05/asr_quality_classifier
#  * branch            main       -> FETCH_HEAD
#    884c655..7afd23b  main       -> origin/main
# Updating 884c655..7afd23b
# Fast-forward
#  src/config.py    | 2 +-
#  src/evaluator.py | 7 ++++---
#  src/model.py     | 2 +-
#  3 files changed, 6 insertions(+), 5 deletions(-)

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 337 bytes | 337.00 KiB/s, done.
# From https://github.com/huanvu05/asr_quality_classifier
#  * branch            main       -> FETCH_HEAD
#    dc09c08..884c655  main       -> origin/main
# Updating dc09c08..884c655
# Fast-forward
#  src/evaluator.py | 1 +
#  1 file changed, 1 insertion(+)

# %%
# !pip install os
# Out:
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os

# %%
# !python main.py \
    --labels-path data/transcripts/training.csv \
    --skip-extraction \
    --features-path data/run_20260604_025406_sota_attention_embeddings.pkl
# Out:
# Starting SOTA Pipeline: run_20260604_031547_sota_attention
# Loading precomputed sequence embeddings from data/run_20260604_025406_sota_attention_embeddings.pkl
# Starting SOTA PyTorch Training (Attention + Focal Loss)...
# 🚀 Kích hoạt chạy song song trên 2 GPUs!
#
# --- Bắt đầu quá trình huấn luyện DNN ---
# Epoch 001/150 | Train Loss: 0.12288 | Val Loss: 0.10399 🌟 (Lưu Checkpoint: best_model_fold_1.pth)
# Epoch 002/150 | Train Loss: 0.10736 | Val Loss: 0.10139 🌟 (Lưu Checkpoint: best_model_fold_1.pth)
# Epoch 003/150 | Train Loss: 0.10901 | Val Loss: 0.10033 🌟 (Lưu Checkpoint: best_model_fold_1.pth)
# Epoch 005/150 | Train Loss: 0.10661 | Val Loss: 0.10276
# Epoch 008/150 | Train Loss: 0.10560 | Val Loss: 0.10003 🌟 (Lưu Checkpoint: best_model_fold_1.pth)
# Epoch 010/150 | Train Loss: 0.10473 | Val Loss: 0.10613
# Epoch 015/150 | Train Loss: 0.10267 | Val Loss: 0.11653
# Epoch 020/150 | Train Loss: 0.09994 | Val Loss: 0.10922
# ...

# %%
# !git pull origin main
# Out:
# From https://github.com/huanvu05/asr_quality_classifier
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !pip install num2words
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 10.2 MB/s eta 0:00:00
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=a94be1ed8cf83b5dcbb957c314babc9cda42dc536af61c1f510fbc0524dbdda6
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built docopt
# ...

# %%
# !python main.py
# Out:
# Starting Chunk & Pool Pipeline: run_20260604_064638_chunk_dnn
# Loading Whisper Encoder (openai/whisper-base) on cuda...
# ...
# preprocessor_config.json: 185kB [00:00, 198MB/s]
# config.json: 1.98kB [00:00, 7.16MB/s]
# model.safetensors: 100%|██████████████████████| 290M/290M [00:02<00:00, 142MB/s]
# Loading weights: 100%|█| 245/245 [00:00<00:00, 2060.64it/s, Materializing param=
# Extracting Chunked Embeddings: 100%|████████| 3500/3500 [09:53<00:00,  5.90it/s]
# Saved 3500 chunked embeddings to data/run_20260604_064638_chunk_dnn_embeddings.pkl
#
# Starting PyTorch DNN Training (80/20 Split)...
# Training on 2800 samples, Validating on 700 samples.
# 🚀 Kích hoạt chạy song song trên 2 GPUs!
#
# --- Bắt đầu quá trình huấn luyện DNN (1 Fold) ---
# ...

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 1), reused 3 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 4.75 KiB | 2.37 MiB/s, done.
# From https://github.com/huanvu05/asr_quality_classifier
#  * branch            main       -> FETCH_HEAD
#    b7e4bd2..bd1640f  main       -> origin/main
# Updating b7e4bd2..bd1640f
# Fast-forward
#  train_asr_alignment_xgboost.py | 331 +++++++++++++++++++++++++++++++++++++++++
#  1 file changed, 331 insertions(+)
#  create mode 100644 train_asr_alignment_xgboost.py

# %%
# !python train_hybrid_datacentric.py
# Out:
# [*] Đang đọc CSV từ: /kaggle/working/asr_quality_classifier/data/transcripts/training.csv
# [*] Đang tải Embedding từ: /kaggle/working/asr_quality_classifier/data/test_embeddings.pkl
# [*] Đang quét cấu trúc thư mục audio để ánh xạ đường dẫn...
# [*] Đang trích xuất đặc trưng vật lý và ghép nối Ma trận lai (Hybrid Matrix)...
# 100%|███████████████████████████████████████| 3500/3500 [01:08<00:00, 51.32it/s]
# [*] Hoàn tất. Kích thước tập dữ liệu Hybrid: X=(3500, 522), y=(3500,)
#
# [*] Đang tính toán Trọng số kép (Dual Sample Weighting)...
#     - Mẫu Đồng thuận (Sạch, W=1.0): 2528
#     - Mẫu Tranh cãi (Nhiễu, W=0.3): 972
#     - Trọng số bù đắp cân bằng lớp (Class Weights): {np.int32(0): np.float64(1.9358407079646018), np.int32(1): np.float64(0.6741140215716487)}
#
# [*] Khởi chạy StratifiedGroupKFold (n_splits=5)...
#     -> Đang huấn luyện Fold 1/5...
#     -> Đang huấn luyện Fold 2/5...
#     -> Đang huấn luyện Fold 3/5...
#     -> Đang huấn luyện Fold 4/5...
# ...

# %%
# !pip install -q transformers librosa pandas numpy scikit-learn seaborn tqdm

# %%
# !python train_wavlm_end2end.py
# Out:
# [*] Đang đọc CSV từ: data/transcripts/training.csv
# [*] Đang quét cấu trúc thư mục audio...
# [*] Tìm thấy 3500 file âm thanh hợp lệ trên tổng số 3500 dòng CSV.
# [*] Đang tính toán Trọng số kép (Dual Sample Weighting)...
#     - Mẫu Đồng thuận (W=1.0): 2528
#     - Mẫu Tranh cãi (W=0.3): 972
#     - Trọng số bù đắp (Class Weights): {np.int64(0): np.float64(1.9358407079646018), np.int64(1): np.float64(0.6741140215716487)}
#
# [*] Khởi chạy StratifiedGroupKFold (n_splits=5)...
# ...
#
# ...
# BẮT ĐẦU FOLD 1/5
# ...
# [*] Khởi tạo mô hình WavLM: microsoft/wavlm-base-plus
# Loading weights: 100%|█| 248/248 [00:00<00:00, 3154.53it/s, Materializing param=
# [*] Áp dụng đóng băng phân tầng (Feature Extractor + Layer 0-7)...
# 🚀 Kích hoạt DataParallel trên 2 GPUs!
# ...
# Epoch 1 Valid: 100%|██████████████████████████| 178/178 [00:25<00:00,  7.03it/s]
# Epoch 1/10 | Train Loss: 0.5356 | Val Macro F1 (Thresh=0.5): 0.4959
# 🌟 Saved New Best Model (F1: 0.4959)
# ...

# %%
# !git pull origin main
# Out:
# From https://github.com/huanvu05/asr_quality_classifier
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !python train_asr_alignment_xgboost.py
# Out:
# [*] ASR Target Device: cuda:0
#
# ...
# GIAI ĐOẠN 1: ASR DECODING & ĐO LƯỜNG LỖI
# ...
# [*] Kích hoạt giải mã ASR song song trên 2 GPUs!
# ...
# Exception in thread Thread-auto_conversion:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py", line 761, in hf_raise_for_status
#     response.raise_for_status()
#   File "/usr/local/lib/python3.12/dist-packages/httpx/_models.py", line 829, in raise_for_status
# Loading weights:   0%|                                  | 0/480 [00:00<?, ?it/s]    raise HTTPStatusError(message, request=request, response=self)
# httpx.HTTPStatusError: Client error '403 Forbidden' for url 'https://huggingface.co/api/models/vinai/PhoWhisper-small/discussions?p=0'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
# Loading weights:   0%| | 1/480 [00:00<00:00, 11814.94it/s, Materializing param=m
# The above exception was the direct cause of the following exception:
# ...

# %%
# !pip install jiwer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 36.0 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 322 bytes | 322.00 KiB/s, done.
# From https://github.com/huanvu05/asr_quality_classifier
#  * branch            main       -> FETCH_HEAD
#    68208dd..dd7c33d  main       -> origin/main
# Updating 68208dd..dd7c33d
# Fast-forward
#  train_deep_audio_fusion.py | 5 ++---
#  1 file changed, 2 insertions(+), 3 deletions(-)

# %%
# !python train_deep_audio_fusion.py
# Out:
# [*] Đang đọc CSV từ: data/transcripts/training.csv
# [*] Tiền xử lý Audio (Resample, Padding) & Trích xuất đặc trưng vật lý...
# 100%|████████████████████████████████████| 3500/3500 [00:00<00:00, 18003.16it/s]
# [*] Áp dụng Label Smoothing cho Dữ liệu Nhiễu...
#
# [*] Khởi chạy StratifiedGroupKFold (n_splits=5)...
# ...
#
# ...
# BẮT ĐẦU FOLD 1/5
# ...
# [*] Đang Load Physical Features (Train)
# 100%|███████████████████████████████████████| 2789/2789 [00:42<00:00, 66.37it/s]
# [*] Đang Load Physical Features (Valid)
# 100%|█████████████████████████████████████████| 711/711 [00:10<00:00, 68.66it/s]
# [*] Khởi tạo WavLM và trích xuất từ Layer 6 (Intermediate)
# Loading weights: 100%|█| 248/248 [00:00<00:00, 3030.11it/s, Materializing param=
# 🚀 Kích hoạt DataParallel trên 2 GPUs!
# Epoch 01/15 | Train Loss: 0.5989 | Val F1 (0.5): 0.4100 🌟 (Saved Best)
# Epoch 02/15 | Train Loss: 0.5592 | Val F1 (0.5): 0.4100
# Epoch 03/15 | Train Loss: 0.5529 | Val F1 (0.5): 0.4100
# ...
